# %%
import pandas as pd

# %%
tourism = pd.read_csv('C:\\Users\\Rushi\\Desktop\\Travel_Project\\tourism_data.csv')
flights = pd.read_csv('C:\\Users\\Rushi\\Desktop\\Travel_Project\\flights_data.csv')
hotels = pd.read_csv('C:\\Users\\Rushi\\Desktop\\Travel_Project\\hotels_data.csv')

# %%
tourism.head()
# Out:
#         Destination          State   Category Best Season  Average Budget  \
# 0               Goa            Goa      Beach     Nov-Feb           30000
# 1      Ladakh (Leh)         Ladakh   Mountain     Mar-Jun           35000
# 2            Jaipur      Rajasthan   Heritage     Oct-Mar           22000
# 3  Varanasi (Kashi)  Uttar Pradesh  Spiritual     Oct-Mar           18000
# 4              Agra  Uttar Pradesh   Heritage     Oct-Mar           22000
#
#    Recommended Trip Duration  Latitude  Longitude   Nearest Airport  \
# 0                          4       NaN        NaN       Goa Airport
# 1                          5       NaN        NaN    Ladakh Airport
# 2                          3       NaN        NaN    Jaipur Airport
# 3                          2       NaN        NaN  Varanasi Airport
# 4                          3       NaN        NaN      Agra Airport
#
#   Popularity Family Friendly  Adventure Score
# 0       High             Yes                6
# ...

# %%
flights.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
hotels.head()
# Out:
#                 Hotel_Name  Hotel_Rating   City     Feature_1       Feature_2  \
# 0       Crowne Plaza Kochi           4.6  kochi  5-star hotel  Free breakfast
# 1     Trident Hotel Cochin           4.5  kochi  5-star hotel  Free breakfast
# 2        The Galaxy Suites           3.8  kochi     Apartment       Sleeps 10
# 3         The Renai cochin           4.2  kochi  4-star hotel  Free breakfast
# 4  Ramada by Wyndham Kochi           4.5  kochi  5-star hotel       Breakfast
#
#       Feature_3     Feature_4            Feature_5           Feature_6  \
# 0    Free Wi-Fi  Free parking                 Pool             Hot tub
# 1         Wi-Fi  Free parking                 Pool    Air conditioning
# 2  Free parking    Free Wi-Fi  No air conditioning  No airport shuttle
# 3    Free Wi-Fi  Free parking                 Pool    Air conditioning
# 4    Free Wi-Fi  Free parking                 Pool    Air conditioning
#
#           Feature_7       Feature_8     Feature_9  Hotel_Price
# ...

# %%
print("Flight Destination Cities")
print(sorted(flights['destination_city'].unique()))
# Out:
# Flight Destination Cities
# ['Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai']

# %%
print("Hotel Cities")
print(list(sorted(hotels['City'].str.title().unique())))
# Out:
# Hotel Cities
# ['Ahmedabad', 'Allahabad', 'Amravati', 'Amritsar', 'Aurangabad', 'Bangalore', 'Bhubaneswar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Dehradun', 'Delhi', 'Durgapur', 'Faridabad', 'Gandhinagar', 'Ghaziabad', 'Goa', 'Guwahati', 'Gwalior', 'Hazaribagh', 'Hyderabad', 'Indore', 'Jaipur', 'Jamshedpur', 'Kanpur', 'Kanyakumari', 'Kashmir', 'Kochi', 'Kolkata', 'Kumarakom', 'Lucknow', 'Ludhiana', 'Mangalore', 'Meerut', 'Mumbai', 'Mysore', 'Nagpur', 'Nashik', 'Noida', 'Patna', 'Pondicherry', 'Pune', 'Raipur', 'Ranchi', 'Sikkim', 'Srinagar', 'Trivandrum', 'Vadodara', 'Varanasi', 'Varkala', 'Vijayawada']

# %%
print("Tourism Destinations")
print(sorted(tourism['Destination'].unique()))
# Out:
# Tourism Destinations
# ...

# %%
data = pd.read_csv('C:\\Users\\Rushi\\Desktop\\Travel_Project\\Air-Clean.csv')

# %%
data.head()
# Out:
#   airline flightNumber origin destination  \
# 0   GoAir          572    Goa   Hyderabad
# 1   GoAir          301    Goa       Delhi
# 2   GoAir          733    Goa      Nagpur
# 3   GoAir          667    Goa     Lucknow
# 4   GoAir          247    Goa      Mumbai
#
#                                           daysOfWeek scheduledDepartureTime  \
# 0                           Thursday,Friday,Saturday                  17:25
# 1                                           Saturday                  12:00
# 2                                           Saturday                  12:10
# 3  Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...                  06:10
# 4                                           Saturday                  11:00
#
#   scheduledArrivalTime    timezone   validFrom     validTo lastUpdated
# 0                18:40  2021-03-27  2020-10-25  2021-03-27  2025-07-16
# 1                14:45  2022-10-23  2022-03-27  2022-10-23  2025-07-16
# ...

# %%
data['origin'].value_counts()
# Out:
# origin
# Mumbai         2912
# Delhi          2634
# Bengaluru      2626
# Hyderabad      2421
# Kolkata        2204
#                ...
# Pakyong          11
# Keshod            9
# Bathinda          7
# Pithoragarh       6
# Cooch-Behar       3
# Name: count, Length: 101, dtype: int64

# %%
data[(data["origin"] == "Hyderabad") & (data["destination"] == "Kochi")]
# Out:
#                  airline flightNumber     origin destination  \
# 1639               GoAir          507  Hyderabad       Kochi
# 1671   Air India Express         1529  Hyderabad       Kochi
# 15726             IndiGo        169.0  Hyderabad       Kochi
# 15727             IndiGo        304.0  Hyderabad       Kochi
# 15728             IndiGo       6334.0  Hyderabad       Kochi
# 15729             IndiGo        667.0  Hyderabad       Kochi
# 15730             IndiGo       6682.0  Hyderabad       Kochi
# 15731             IndiGo       6682.0  Hyderabad       Kochi
# 15732             IndiGo       6682.0  Hyderabad       Kochi
# 15733             IndiGo       6703.0  Hyderabad       Kochi
# 15734             IndiGo       6707.0  Hyderabad       Kochi
# 21186             IndiGo          169  Hyderabad       Kochi
# 21187             IndiGo          187  Hyderabad       Kochi
# 21188             IndiGo          304  Hyderabad       Kochi
# ...
