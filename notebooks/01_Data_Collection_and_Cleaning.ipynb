# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
tourism = pd.read_csv("../data/raw/tourism_data.csv")

hotels = pd.read_csv("../data/raw/hotels_data.csv")

flights = pd.read_csv("../data/raw/flights.csv")

flight_cost = pd.read_csv("../data/raw/flight_cost.csv")

# %%
print("Tourism :", tourism.shape)
print("Hotels :", hotels.shape)
print("Flights :", flights.shape)
print("Flight Cost :", flight_cost.shape)
# Out:
# Tourism : (92, 12)
# Hotels : (1101, 13)
# Flights : (33734, 11)
# Flight Cost : (1423, 3)

# %%
def dataset_summary(df, name):

    print("=" * 70)
    print(f"{name.upper()} DATASET")
    print("=" * 70)

    print(f"\nShape: {df.shape}")

    print("\nColumns:")
    print(df.columns.tolist())

    print("\nData Types:")
    print(df.dtypes)

    print("\nMissing Values:")
    print(df.isnull().sum())

    print("\nDuplicate Rows:")
    print(df.duplicated().sum())


    print("\nFirst 5 Rows:")
    display(df.head())

# %%
dataset_summary(tourism, "Tourism")
# Out:
# ...
# TOURISM DATASET
# ...
#
# Shape: (92, 12)
#
# Columns:
# ['Destination', 'State', 'Category', 'Best Season', 'Average Budget', 'Recommended Trip Duration', 'Latitude', 'Longitude', 'Nearest Airport', 'Popularity', 'Family Friendly', 'Adventure Score']
#
# Data Types:
# Destination                      str
# State                            str
# Category                         str
# Best Season                      str
# Average Budget                 int64
# Recommended Trip Duration      int64
# Latitude                     float64
# Longitude                    float64
# Nearest Airport                  str
# Popularity                       str
# Family Friendly                  str
# Adventure Score                int64
# dtype: object
#
# Missing Values:
# Destination                   0
# State                         0
# Category                      0
# Best Season                   0
# Average Budget                0
# Recommended Trip Duration     0
# ...

# %%
dataset_summary(hotels, "Hotels")
# Out:
# ...
# HOTELS DATASET
# ...
#
# Shape: (1101, 13)
#
# Columns:
# ['Hotel_Name', 'Hotel_Rating', 'City', 'Feature_1', 'Feature_2', 'Feature_3', 'Feature_4', 'Feature_5', 'Feature_6', 'Feature_7', 'Feature_8', 'Feature_9', 'Hotel_Price']
#
# Data Types:
# Hotel_Name          str
# Hotel_Rating    float64
# City                str
# Feature_1           str
# Feature_2           str
# Feature_3           str
# Feature_4           str
# Feature_5           str
# Feature_6           str
# Feature_7           str
# Feature_8           str
# Feature_9           str
# Hotel_Price     float64
# dtype: object
#
# Missing Values:
# Hotel_Name      0
# Hotel_Rating    0
# City            0
# Feature_1       0
# Feature_2       0
# Feature_3       0
# Feature_4       0
# Feature_5       0
# Feature_6       0
# Feature_7       0
# Feature_8       0
# Feature_9       0
# Hotel_Price     0
# dtype: int64
#
# Duplicate Rows:
# 18
#
# First 5 Rows:
# ...

# %%
dataset_summary(flights, "Flights")
# Out:
# ...
# FLIGHTS DATASET
# ...
#
# Shape: (33734, 11)
#
# Columns:
# ['airline', 'flightNumber', 'origin', 'destination', 'daysOfWeek', 'scheduledDepartureTime', 'scheduledArrivalTime', 'timezone', 'validFrom', 'validTo', 'lastUpdated']
#
# Data Types:
# airline                   str
# flightNumber              str
# origin                    str
# destination               str
# daysOfWeek                str
# scheduledDepartureTime    str
# scheduledArrivalTime      str
# timezone                  str
# validFrom                 str
# validTo                   str
# lastUpdated               str
# dtype: object
#
# Missing Values:
# airline                   0
# flightNumber              0
# origin                    0
# destination               0
# daysOfWeek                0
# scheduledDepartureTime    0
# scheduledArrivalTime      0
# timezone                  0
# validFrom                 0
# validTo                   0
# lastUpdated               0
# dtype: int64
#
# Duplicate Rows:
# 118
# ...

# %%
dataset_summary(flight_cost, "Flight Cost")
# Out:
# ...
# FLIGHT COST DATASET
# ...
#
# Shape: (1423, 3)
#
# Columns:
# ['origin', 'destination', 'avg_flight_cost_inr']
#
# Data Types:
# origin                   str
# destination              str
# avg_flight_cost_inr    int64
# dtype: object
#
# Missing Values:
# origin                 0
# destination            0
# avg_flight_cost_inr    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# First 5 Rows:
#   origin destination  avg_flight_cost_inr
# 0    Goa   Hyderabad                 3900
# 1    Goa       Delhi                 3100
# 2    Goa      Nagpur                 3400
# 3    Goa     Lucknow                 3000
# 4    Goa      Mumbai                 4000

# %%
hotels[hotels.duplicated()]
# Out:
#                                              Hotel_Name  Hotel_Rating  \
# 5                                      The Renai cochin           4.2
# 88                                        Sunny's World           4.2
# 246   Country Inn & Suites by Radisson, Bengaluru He...           4.1
# 315            Hotel Gargee Grand | Best Hotel in Patna           4.1
# 420                                  Best Western Bliss           4.1
# 434                                   Little Chef Hotel           4.3
# 500                                   Hotel Ganga Sagar           4.3
# 601                                      Hotel Ambience           3.9
# 628                                 Hotel Rangoli Pearl           4.1
# 634                          The Peerless Inn, Durgapur           4.0
# 647                              Morvee Hotels Durgapur           4.4
# 654             Treebo Trend Winsome Banquet And Resort           4.6
# ...

# %%
hotel_duplicates = hotels[hotels.duplicated(keep=False)]
hotel_duplicates.sort_values(by=hotels.columns.tolist())
# Out:
#                                              Hotel_Name  Hotel_Rating  \
# 416                                  Best Western Bliss           4.1
# 420                                  Best Western Bliss           4.1
# 1081                              Clafouti Beach Resort           4.1
# 1099                              Clafouti Beach Resort           4.1
# 244   Country Inn & Suites by Radisson, Bengaluru He...           4.1
# 246   Country Inn & Suites by Radisson, Bengaluru He...           4.1
# 591                                      Hotel Ambience           3.9
# 601                                      Hotel Ambience           3.9
# 969                                  Hotel Four Element           4.4
# 989                                  Hotel Four Element           4.4
# 485                                   Hotel Ganga Sagar           4.3
# 500                                   Hotel Ganga Sagar           4.3
# ...

# %%
flight_duplicates = flights[flights.duplicated(keep=False)]
flight_duplicates.sort_values(by=flights.columns.tolist())
# Out:
#          airline flightNumber     origin destination  \
# 3290   Air India        588.0      Kochi   Bengaluru
# 17003  Air India        588.0      Kochi   Bengaluru
# 8600   Air India          680  Mangalore      Mumbai
# 19702  Air India          680  Mangalore      Mumbai
# 8685   Air India          680  Mangalore      Mumbai
# ...          ...          ...        ...         ...
# 19698   SpiceJet         4010  Mangalore   Bengaluru
# 8704    SpiceJet         4034  Mangalore   Hyderabad
# 19757   SpiceJet         4034  Mangalore   Hyderabad
# 8705    SpiceJet         8907  Mangalore       Delhi
# 19758   SpiceJet         8907  Mangalore       Delhi
#
#                                               daysOfWeek  \
# 3290      Sunday,Monday,Tuesday,Thursday,Friday,Saturday
# 17003     Sunday,Monday,Tuesday,Thursday,Friday,Saturday
# 8600   Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...
# 19702  Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...
# ...

# %%
# Hotels
hotels = hotels.drop_duplicates().reset_index(drop=True)

# Flights
flights = flights.drop_duplicates().reset_index(drop=True)

## Tousism
tourism = tourism.drop(columns=['Latitude'	,'Longitude'],axis=0)

# %%
print(hotels.shape)
print(flights.shape)
# Out:
# (1083, 13)
# (33616, 11)

# %%
tourism.to_csv("../data/cleaned/tourism_data_clean.csv", index=False)

hotels.to_csv("../data/cleaned/hotels_data_clean.csv", index=False)

flights.to_csv("../data/cleaned/flights_clean.csv", index=False)

flight_cost.to_csv("../data/cleaned/flight_cost_clean.csv", index=False)
